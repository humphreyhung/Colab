# %% [markdown]
# <a href="https://colab.research.google.com/github/humphreyhung/Colab/blob/main/%E5%9C%96%E8%A1%A8%E6%B8%AC%E8%A9%A6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pylab as plt
import numpy as np
x=np.random.uniform(0,1,100)#平均份佈
y=np.random.uniform(0,1,100)
plt.scatter(x,y,c='r')
plt.show()
