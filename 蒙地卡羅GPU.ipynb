# %% [markdown]
# <a href="https://colab.research.google.com/github/humphreyhung/Colab/blob/main/%E8%92%99%E5%9C%B0%E5%8D%A1%E7%BE%85GPU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import tensorflow as tf
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
import time
import numpy as np
batch=100_000_000
epoch=4000
incircle=0
for e in range(epoch):
    t1=time.time()
    #points = [np.random.uniform(0, 1, batch), np.random.uniform(0, 1, batch)]
    points=[tf.random.uniform(shape=[batch]), tf.random.uniform(shape=[batch])]
    #dist = np.sqrt(np.square(points[0]) + np.square(points[1]))
    dist=tf.sqrt(tf.square(points[0])+tf.square(points[1]))
    #incircle+=np.where(dist<=1)[0].shape[0]
    incircle += tf.where(dist <= 1).shape[0]
    t2=time.time()
    print(f'epoch:{e+1} ,花費時間:{t2-t1:.4f}秒, pi={incircle/((e+1)*batch)*4}')
# Out:
# epoch:1 ,花費時間:3.2660秒, pi=3.14148832
# epoch:2 ,花費時間:0.0279秒, pi=3.14160498
# epoch:3 ,花費時間:0.0323秒, pi=3.1415114
# epoch:4 ,花費時間:0.0305秒, pi=3.14156105
# epoch:5 ,花費時間:0.0306秒, pi=3.14156604
# epoch:6 ,花費時間:0.2150秒, pi=3.1415509733333336
# epoch:7 ,花費時間:0.0305秒, pi=3.1415647942857143
# epoch:8 ,花費時間:0.0305秒, pi=3.14155734
# epoch:9 ,花費時間:0.0326秒, pi=3.1415358133333333
# epoch:10 ,花費時間:0.0306秒, pi=3.141558228
# epoch:11 ,花費時間:0.0304秒, pi=3.1415806218181817
# epoch:12 ,花費時間:0.0305秒, pi=3.1416046466666665
# epoch:13 ,花費時間:0.0304秒, pi=3.1416299476923077
# epoch:14 ,花費時間:0.0304秒, pi=3.1416486942857142
# epoch:15 ,花費時間:0.0305秒, pi=3.141637805333333
# epoch:16 ,花費時間:0.0305秒, pi=3.1416450025
# epoch:17 ,花費時間:0.0308秒, pi=3.141642722352941
# epoch:18 ,花費時間:0.0308秒, pi=3.1416382888888887
# epoch:19 ,花費時間:0.0309秒, pi=3.141633292631579
# epoch:20 ,花費時間:0.0337秒, pi=3.14162477
# epoch:21 ,花費時間:0.0312秒, pi=3.141629419047619
# epoch:22 ,花費時間:0.0319秒, pi=3.1416275236363638
# epoch:23 ,花費時間:0.0372秒, pi=3.141614046956522
# epoch:24 ,花費時間:0.0309秒, pi=3.141615245
# epoch:25 ,花費時間:0.0309秒, pi=3.1416183632
# epoch:26 ,花費時間:0.0309秒, pi=3.1416178476923076
# epoch:27 ,花費時間:0.0309秒, pi=3.141619573333333
# epoch:28 ,花費時間:0.0308秒, pi=3.141612857142857
# epoch:29 ,花費時間:0.0309秒, pi=3.1416225696551723
# epoch:30 ,花費時間:0.0310秒, pi=3.1416248093333334
# epoch:31 ,花費時間:0.0412秒, pi=3.141614825806452
# epoch:32 ,花費時間:0.0216秒, pi=3.141611395
# epoch:33 ,花費時間:0.0309秒, pi=3.141602872727273
# epoch:34 ,花費時間:0.0309秒, pi=3.141600654117647
# epoch:35 ,花費時間:0.0309秒, pi=3.141602403428571
# epoch:36 ,花費時間:0.0309秒, pi=3.1415989933333335
# epoch:37 ,花費時間:0.0309秒, pi=3.1416011664864865
# epoch:38 ,花費時間:0.0309秒, pi=3.1415978936842106
# epoch:39 ,花費時間:0.0310秒, pi=3.141602637948718
# epoch:40 ,花費時間:0.0309秒, pi=3.141604017
# epoch:41 ,花費時間:0.0309秒, pi=3.1416014585365852
# epoch:42 ,花費時間:0.0309秒, pi=3.141602597142857
# epoch:43 ,花費時間:0.0309秒, pi=3.1416034093023257
# epoch:44 ,花費時間:0.0308秒, pi=3.14160134
# epoch:45 ,花費時間:0.0310秒, pi=3.1416028684444446
# epoch:46 ,花費時間:0.0308秒, pi=3.1415952304347825
# epoch:47 ,花費時間:0.0309秒, pi=3.141595210212766
# epoch:48 ,花費時間:0.0309秒, pi=3.1415994675
# epoch:49 ,花費時間:0.0309秒, pi=3.14159793877551
# epoch:50 ,花費時間:0.0309秒, pi=3.1415988008
# epoch:51 ,花費時間:0.0308秒, pi=3.1416022360784313
# epoch:52 ,花費時間:0.0309秒, pi=3.141598207692308
# epoch:53 ,花費時間:0.0309秒, pi=3.1415938633962264
# epoch:54 ,花費時間:0.0309秒, pi=3.14159664
# epoch:55 ,花費時間:0.0309秒, pi=3.1415973527272727
# epoch:56 ,花費時間:0.0308秒, pi=3.1415995307142857
# epoch:57 ,花費時間:0.0309秒, pi=3.1416018863157893
# epoch:58 ,花費時間:0.0309秒, pi=3.141604328275862
# epoch:59 ,花費時間:0.0309秒, pi=3.1416065837288136
# epoch:60 ,花費時間:0.0309秒, pi=3.1416095526666665
# epoch:61 ,花費時間:0.0308秒, pi=3.141605481967213
# epoch:62 ,花費時間:0.0309秒, pi=3.1416032038709676
# epoch:63 ,花費時間:0.0309秒, pi=3.1416057047619046
# epoch:64 ,花費時間:0.0308秒, pi=3.14160555625
# epoch:65 ,花費時間:0.0309秒, pi=3.141602713846154
# epoch:66 ,花費時間:0.0310秒, pi=3.141603350909091
# epoch:67 ,花費時間:0.0309秒, pi=3.1415985235820894
# epoch:68 ,花費時間:0.0309秒, pi=3.141596887647059
# epoch:69 ,花費時間:0.0309秒, pi=3.1415964620289856
# epoch:70 ,花費時間:0.0309秒, pi=3.1415931942857145
# epoch:71 ,花費時間:0.0309秒, pi=3.141592170140845
# epoch:72 ,花費時間:0.0309秒, pi=3.1415936533333335
# epoch:73 ,花費時間:0.0309秒, pi=3.141593670136986
# epoch:74 ,花費時間:0.0309秒, pi=3.14159485027027
# epoch:75 ,花費時間:0.0309秒, pi=3.1415934074666665
# epoch:76 ,花費時間:0.0309秒, pi=3.1415923521052633
# epoch:77 ,花費時間:0.0309秒, pi=3.1415903703896104
# epoch:78 ,花費時間:0.0309秒, pi=3.1415879764102566
# epoch:79 ,花費時間:0.0309秒, pi=3.1415871908860757
# epoch:80 ,花費時間:0.0309秒, pi=3.141585101
# epoch:81 ,花費時間:0.0309秒, pi=3.141587695308642
# epoch:82 ,花費時間:0.0309秒, pi=3.14158751902439
# epoch:83 ,花費時間:0.0309秒, pi=3.1415907344578313
# epoch:84 ,花費時間:0.0308秒, pi=3.1415910442857142
# epoch:85 ,花費時間:0.0317秒, pi=3.1415902767058825
# epoch:86 ,花費時間:0.0311秒, pi=3.1415894125581394
# epoch:87 ,花費時間:0.0410秒, pi=3.141589476781609
# epoch:88 ,花費時間:0.0309秒, pi=3.141592947272727
# epoch:89 ,花費時間:0.0309秒, pi=3.141591782921348
# epoch:90 ,花費時間:0.0342秒, pi=3.1415934435555557
# epoch:91 ,花費時間:0.0317秒, pi=3.141596516923077
# epoch:92 ,花費時間:0.0310秒, pi=3.1415978730434784
# epoch:93 ,花費時間:0.0308秒, pi=3.141595386666667
# epoch:94 ,花費時間:0.0309秒, pi=3.1415937361702126
# epoch:95 ,花費時間:0.0310秒, pi=3.1415951305263157
# epoch:96 ,花費時間:0.0310秒, pi=3.141594485416667
# epoch:97 ,花費時間:0.0309秒, pi=3.1415931101030927
# epoch:98 ,花費時間:0.0308秒, pi=3.141594257959184
# epoch:99 ,花費時間:0.0321秒, pi=3.141595551919192
# epoch:100 ,花費時間:0.0309秒, pi=3.1415963076
# epoch:101 ,花費時間:0.0305秒, pi=3.1415981172277228
# epoch:102 ,花費時間:0.0314秒, pi=3.1415978874509802
# epoch:103 ,花費時間:0.0309秒, pi=3.141598569708738
# epoch:104 ,花費時間:0.0312秒, pi=3.141598629615385
# epoch:105 ,花費時間:0.0310秒, pi=3.1415998678095236
# epoch:106 ,花費時間:0.0350秒, pi=3.141600320754717
# epoch:107 ,花費時間:0.0289秒, pi=3.1416010306542055
# epoch:108 ,花費時間:0.0315秒, pi=3.141602051111111
# epoch:109 ,花費時間:0.0309秒, pi=3.1416010543119266
# epoch:110 ,花費時間:0.0308秒, pi=3.1416018072727274
# epoch:111 ,花費時間:0.0310秒, pi=3.1416011203603604
# epoch:112 ,花費時間:0.0310秒, pi=3.14160119
# epoch:113 ,花費時間:0.0309秒, pi=3.1415984842477878
# epoch:114 ,花費時間:0.0411秒, pi=3.1415978343859647
# epoch:115 ,花費時間:0.0308秒, pi=3.141596453565217
# epoch:116 ,花費時間:0.0321秒, pi=3.141594009655172
# epoch:117 ,花費時間:0.0310秒, pi=3.141595292991453
# epoch:118 ,花費時間:0.0329秒, pi=3.1415976162711865
# epoch:119 ,花費時間:0.0314秒, pi=3.1416000521008405
# epoch:120 ,花費時間:0.0330秒, pi=3.141598772
# epoch:121 ,花費時間:0.0309秒, pi=3.1416011831404957
# epoch:122 ,花費時間:0.0308秒, pi=3.1416018632786886
# epoch:123 ,花費時間:0.0309秒, pi=3.141602397398374
# epoch:124 ,花費時間:0.0309秒, pi=3.1416018996774193
# epoch:125 ,花費時間:0.0309秒, pi=3.14160096224
# epoch:126 ,花費時間:0.0308秒, pi=3.1416018774603174
# epoch:127 ,花費時間:0.0310秒, pi=3.141603503937008
# epoch:128 ,花費時間:0.0310秒, pi=3.1416054946875
# epoch:129 ,花費時間:0.0308秒, pi=3.1416049705426357
# epoch:130 ,花費時間:0.0309秒, pi=3.141606520923077
# epoch:131 ,花費時間:0.0309秒, pi=3.1416064809160305
# epoch:132 ,花費時間:0.0309秒, pi=3.141605818181818
# epoch:133 ,花費時間:0.0309秒, pi=3.1416049118796994
# epoch:134 ,花費時間:0.0309秒, pi=3.1416062641791043
# epoch:135 ,花費時間:0.0309秒, pi=3.141607649777778
# epoch:136 ,花費時間:0.0309秒, pi=3.1416059029411763
# epoch:137 ,花費時間:0.0308秒, pi=3.1416050122627737
# epoch:138 ,花費時間:0.0309秒, pi=3.1416039576811596
# epoch:139 ,花費時間:0.0308秒, pi=3.1416050405755396
# epoch:140 ,花費時間:0.0309秒, pi=3.1416059442857143
# epoch:141 ,花費時間:0.0309秒, pi=3.1416055492198582
# epoch:142 ,花費時間:0.0309秒, pi=3.141603514366197
# epoch:143 ,花費時間:0.0310秒, pi=3.1416034492307694
# epoch:144 ,花費時間:0.0308秒, pi=3.1416031697222224
# epoch:145 ,花費時間:0.0310秒, pi=3.1416020830344826
# epoch:146 ,花費時間:0.0309秒, pi=3.141600757260274
# epoch:147 ,花費時間:0.0309秒, pi=3.1416005170068027
# epoch:148 ,花費時間:0.0309秒, pi=3.1416007197297295
# epoch:149 ,花費時間:0.0309秒, pi=3.141600965637584
# epoch:150 ,花費時間:0.0309秒, pi=3.1415999248
# epoch:151 ,花費時間:0.0309秒, pi=3.1416011525827816
# epoch:152 ,花費時間:0.0309秒, pi=3.141602152368421
# epoch:153 ,花費時間:0.0309秒, pi=3.141603499607843
# epoch:154 ,花費時間:0.0308秒, pi=3.1416036379220778
# epoch:155 ,花費時間:0.0309秒, pi=3.141603284645161
# epoch:156 ,花費時間:0.0309秒, pi=3.1416035966666667
# epoch:157 ,花費時間:0.0309秒, pi=3.1416023215286626
# epoch:158 ,花費時間:0.0309秒, pi=3.141603595949367
# epoch:159 ,花費時間:0.0309秒, pi=3.141603558490566
# epoch:160 ,花費時間:0.0309秒, pi=3.14160317525
# epoch:161 ,花費時間:0.0308秒, pi=3.141604630062112
# epoch:162 ,花費時間:0.0309秒, pi=3.1416022508641976
# epoch:163 ,花費時間:0.0309秒, pi=3.1416030731288345
# epoch:164 ,花費時間:0.0309秒, pi=3.1416030614634147
# epoch:165 ,花費時間:0.0309秒, pi=3.141603732121212
# epoch:166 ,花費時間:0.0309秒, pi=3.1416043609638553
# epoch:167 ,花費時間:0.0310秒, pi=3.141605988023952
# epoch:168 ,花費時間:0.0309秒, pi=3.141605563095238
# epoch:169 ,花費時間:0.0309秒, pi=3.1416041990532544
# epoch:170 ,花費時間:0.0308秒, pi=3.141605414117647
# epoch:171 ,花費時間:0.0310秒, pi=3.141606468538012
# epoch:172 ,花費時間:0.0309秒, pi=3.141607532790698
# epoch:173 ,花費時間:0.0310秒, pi=3.141606376184971
# epoch:174 ,花費時間:0.0316秒, pi=3.141604577241379
# epoch:175 ,花費時間:0.0308秒, pi=3.1416048898285713
# epoch:176 ,花費時間:0.0309秒, pi=3.141606806363636
# epoch:177 ,花費時間:0.0310秒, pi=3.141606692655367
# epoch:178 ,花費時間:0.0310秒, pi=3.1416069683146066
# epoch:179 ,花費時間:0.0310秒, pi=3.141607207150838
# epoch:180 ,花費時間:0.0309秒, pi=3.14160756
# epoch:181 ,花費時間:0.0310秒, pi=3.141609129281768
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-2399817417> in <cell line: 0>()
#      14     dist=tf.sqrt(tf.square(points[0])+tf.square(points[1]))
#      15     #incircle+=np.where(dist<=1)[0].shape[0]
# ---> 16     incircle += tf.where(dist <= 1).shape[0]
#      17     t2=time.time()
#      18     print(f'epoch:{e+1} ,花費時間:{t2-t1:.4f}秒, pi={incircle/((e+1)*batch)*4}')
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1258       # Fallback dispatch system (dispatch v1):
#    1259       try:
# -> 1260         return dispatch_target(*args, **kwargs)
#    1261       except (TypeError, ValueError):
#    1262         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/array_ops.py in where_v2(condition, x, y, name)
#    4647       condition = ops.convert_to_tensor(
#    4648           condition, preferred_dtype=dtypes.bool, name="condition")
# -> 4649       return gen_array_ops.where(condition=condition, name=name)
#    4650   elif x is not None and y is not None:
#    4651     return gen_math_ops.select_v2(condition=condition, t=x, e=y, name=name)
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/ops/gen_array_ops.py in where(condition, name)
#   13163   if tld.is_eager:
#   13164     try:
# > 13165       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   13166         _ctx, "Where", name, condition)
#   13167       return _result
#
# KeyboardInterrupt:
