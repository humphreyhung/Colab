# %% [markdown]
# <a href="https://colab.research.google.com/github/humphreyhung/Colab/blob/main/%E5%9C%96%E7%89%87.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive #輸入外載套件
import cv2
from google.colab.patches import cv2_imshow
drive.mount("/data") #mount /MyDrive on /data/MyDrive
pic_path="/data/MyDrive/Colab Notebooks"
img=cv2.imread(f'{pic_path}/tiger.jpg', cv2.IMREAD_UNCHANGED)
#cv2_imshow(img)
import pylab as plt
img=cv2.resize(img,(800,600), interpolation=cv2.INTER_LINEAR)
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
# Out:
# Drive already mounted at /data; to attempt to forcibly remount, call drive.mount("/data", force_remount=True).
